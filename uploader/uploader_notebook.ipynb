# %%
import json

with open("./exercises_list.json") as file:
    data = json.load(file)

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
df["tags"] = df["tags"].apply(lambda x: ",".join(x))
df["tests"] = df["tests"].apply(lambda x: "\n".join(x))

# %%
df
# Out:
#                                                title  \
# 0                                   How Edabit Works
# 1                      Return the Sum of Two Numbers
# 2                       Convert Minutes into Seconds
# 3     Return the Next Number from the Integer Passed
# 4                                 Area of a Triangle
# ...                                              ...
# 1462                         Strong Password Checker
# 1463                                 Rational Number
# 1464                                 Additive Number
# 1465                            First n Digits of Pi
# 1466                             Who's That Polygon?
#
#                                             description        publishedBy  \
# 0     <p><span>This is an introduction to how challe...               Matt
# 1     <p><span>Create a function that takes two numb...          formateur
# 2     <p><span>Write a function that takes an intege...               Matt
# ...
